# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
import seaborn as sns
# %matplotlib inline

# %%
s1 = Series(np.random.randn(1000))

# %%
plt.hist(s1)
# Out:
# (array([ 15.,  43.,  98., 151., 234., 198., 144.,  75.,  31.,  11.]),
#  array([-2.66682021, -2.11753278, -1.56824536, -1.01895793, -0.4696705 ,
#          0.07961692,  0.62890435,  1.17819178,  1.7274792 ,  2.27676663,
#          2.82605406]),
#  <a list of 10 Patch objects>)

# %%
s1.plot(kind='kde')

# %%
sns.distplot(s1, bins=20, hist=True, kde=True, rug=True)
# Out:
# /Users/she/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(s1, shade=True, color='r')

# %%
sns.rugplot(s1, color='g', height=1)
