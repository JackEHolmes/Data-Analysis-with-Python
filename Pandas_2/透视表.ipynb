# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_excel('../homework/sales-funnel.xlsx')

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
pd.pivot_table(df, index=['Name'], aggfunc='sum' ).sort_values('Price', ascending=False)
# Out:
#                               Account   Price  Quantity
# Name
# Keeling LLC                    688981  100000         5
# Koepp Ltd                     1459666   70000         4
# Herman LLC                     141962   65000         2
# Kiehn-Spinka                   146832   65000         2
# Kulas Inc                      437790   50000         3
# Trantow-Barrows               2143398   45000         4
# Barton LLC                     740150   35000         1
# Fritsch, Russel and Anderson   737550   35000         1
# Purdy-Kunde                    163416   30000         1
# Stokes LLC                     478688   15000         2
# Kassulke, Ondricka and Metz    307599    7000         3
# Jerde-Hilpert                  412290    5000         2

# %%
pd.pivot_table(df, index=['Name', 'Rep', 'Manager'])
# Out:
#                                                           Account   Price  \
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley    740150   35000
# Fritsch, Russel and Anderson Craig Booker  Debra Henley    737550   35000
# Herman LLC                   Cedric Moss   Fred Anderson   141962   65000
# Jerde-Hilpert                John Smith    Debra Henley    412290    5000
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson   307599    7000
# Keeling LLC                  Wendy Yule    Fred Anderson   688981  100000
# Kiehn-Spinka                 Daniel Hilton Debra Henley    146832   65000
# Koepp Ltd                    Wendy Yule    Fred Anderson   729833   35000
# Kulas Inc                    Daniel Hilton Debra Henley    218895   25000
# Purdy-Kunde                  Cedric Moss   Fred Anderson   163416   30000
# Stokes LLC                   Cedric Moss   Fred Anderson   239344    7500
# ...

# %%
pd.pivot_table(df, index=['Name', 'Rep'], aggfunc='sum', values='Price')\
.combine_first(
pd.pivot_table(df, index=['Name', 'Rep'], aggfunc='mean', values='Quantity')\
)
# Out:
#                                              Price  Quantity
# Name                         Rep
# Barton LLC                   John Smith      35000  1.000000
# Fritsch, Russel and Anderson Craig Booker    35000  1.000000
# Herman LLC                   Cedric Moss     65000  2.000000
# Jerde-Hilpert                John Smith       5000  2.000000
# Kassulke, Ondricka and Metz  Wendy Yule       7000  3.000000
# Keeling LLC                  Wendy Yule     100000  5.000000
# Kiehn-Spinka                 Daniel Hilton   65000  2.000000
# Koepp Ltd                    Wendy Yule      70000  2.000000
# Kulas Inc                    Daniel Hilton   50000  1.500000
# Purdy-Kunde                  Cedric Moss     30000  1.000000
# Stokes LLC                   Cedric Moss     15000  1.000000
# Trantow-Barrows              Craig Booker    45000  1.333333

# %%
pd.pivot_table(df, index=['Name', 'Rep'], aggfunc='sum', values=['Price','Quantity'], columns=['Product'], fill_value=0)
# Out:
#                                              Price                      \
# Product                                        CPU Maintenance Monitor
# Name                         Rep
# Barton LLC                   John Smith      35000           0       0
# Fritsch, Russel and Anderson Craig Booker    35000           0       0
# Herman LLC                   Cedric Moss     65000           0       0
# Jerde-Hilpert                John Smith          0        5000       0
# Kassulke, Ondricka and Metz  Wendy Yule          0        7000       0
# Keeling LLC                  Wendy Yule     100000           0       0
# Kiehn-Spinka                 Daniel Hilton   65000           0       0
# Koepp Ltd                    Wendy Yule      65000           0    5000
# Kulas Inc                    Daniel Hilton   40000           0       0
# Purdy-Kunde                  Cedric Moss     30000           0       0
# Stokes LLC                   Cedric Moss         0        5000       0
# ...
